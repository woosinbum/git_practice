# %%
cd
# Out:
# C:\Users\User

# %%
import pandas as pd
import numpy as np
from itertools import product # iterative combinations
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.linear_model import *
from sklearn.cluster import KMeans
from tslearn.clustering import *

from statsmodels import datasets
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %%
df4 = pd.read_csv('./Desktop/csv/df4.csv')

# %%
df6 = pd.read_csv('./Desktop/csv/df6.csv')

# %%
df4.head()
# Out:
#          date  shop_id  item_category_id  date_block_num  item_id  item_price  \
# 0  2013-01-01        2                40               0     8665       299.0
# 1  2013-01-01       54                 2               0     5641      2390.0
# 2  2013-01-01       54                 2               0     5635      2390.0
# 3  2013-01-01       54                 2               0     5574       699.0
# 4  2013-01-01       54                 2               0     5572      1590.0
#
#    item_cnt_day year_month  year  month  day  weekday  weekend  sale_day  \
# 0           1.0    2013-01  2013      1    1        1        0     299.0
# 1           1.0    2013-01  2013      1    1        1        0    2390.0
# 2           1.0    2013-01  2013      1    1        1        0    2390.0
# 3           1.0    2013-01  2013      1    1        1        0     699.0
# 4           2.0    2013-01  2013      1    1        1        0    3180.0
#
# ...

# %%
df6[df6.cnt_month==0]
# Out:
#          Unnamed: 0        date  shop_id  item_category_id  date_block_num  \
# 244             244  2013-01-01       27                62               0
# 508             508  2013-01-01       41                 6               0
# 1161           1161  2013-01-01       19                72               0
# 2353           2353  2013-01-02        6                58               0
# 2587           2587  2013-01-02       22                 2               0
# ...             ...         ...      ...               ...             ...
# 2931154     2931154  2015-10-29       50                55              33
# 2932010     2932010  2015-10-30       47                24              33
# 2932156     2932156  2015-10-30       52                40              33
# 2935431     2935431  2015-10-31       38                23              33
# 2935599     2935599  2015-10-31       47                24              33
#
# ...

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4e1243bd22c6> in <module>
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
cd
# Out:
# C:\Users\User

# %%
test=pd.read_csv('./Desktop/kaggle_semi_project/test.csv')

# %%
test.drop(['ID'],axis=1)
# Out:
#         shop_id  item_id
# 0             5     5037
# 1             5     5320
# 2             5     5233
# 3             5     5232
# 4             5     5268
# ...         ...      ...
# 214195       45    18454
# 214196       45    16188
# 214197       45    15757
# 214198       45    19648
# 214199       45      969
#
# [214200 rows x 2 columns]

# %%
test['cnt_month'] = 0

# %%
test['cnt_month']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 214195    0
# 214196    0
# 214197    0
# 214198    0
# 214199    0
# Name: cnt_month, Length: 214200, dtype: int64

# %%
df6.head()
# Out:
#    Unnamed: 0        date  shop_id  item_category_id  date_block_num  item_id  \
# 0           0  2013-01-01        2                40               0     8665
# 1           1  2013-01-01       54                 2               0     5641
# 2           2  2013-01-01       54                 2               0     5635
# 3           3  2013-01-01       54                 2               0     5574
# 4           4  2013-01-01       54                 2               0     5572
#
#    item_price  item_cnt_day year_month  year  month  day  weekday  weekend  \
# 0       299.0           1.0    2013-01  2013      1    1        1        0
# 1      2390.0           1.0    2013-01  2013      1    1        1        0
# 2      2390.0           1.0    2013-01  2013      1    1        1        0
# 3       699.0           1.0    2013-01  2013      1    1        1        0
# 4      1590.0           2.0    2013-01  2013      1    1        1        0
#
#    sale_day item_category_name  \
# ...

# %%
# Out:
#             ID  shop_id  item_id  cnt_month
# 0            0        5     5037          0
# 1            1        5     5320          0
# 2            2        5     5233          0
# 3            3        5     5232          0
# 4            4        5     5268          0
# ...        ...      ...      ...        ...
# 214195  214195       45    18454          0
# 214196  214196       45    16188          0
# 214197  214197       45    15757          0
# 214198  214198       45    19648          0
# 214199  214199       45      969          0
#
# [214200 rows x 4 columns]

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935843 entries, 0 to 2935842
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   date                object
#  2   shop_id             int64
#  3   item_category_id    int64
#  4   date_block_num      int64
#  5   item_id             int64
#  6   item_price          float64
#  7   item_cnt_day        float64
#  8   year_month          object
#  9   year                int64
#  10  month               int64
#  11  day                 int64
#  12  weekday             int64
#  13  weekend             int64
#  14  sale_day            float64
#  15  item_category_name  object
#  16  item_name           object
#  17  km_cluster          int64
#  18  shop_cluster        int64
#  19  cnt_month           float64
# dtypes: float64(4), int64(12), object(4)
# memory usage: 448.0+ MB

# %%
df6.columns
# Out:
# Index(['Unnamed: 0', 'date', 'shop_id', 'item_category_id', 'date_block_num',
#        'item_id', 'item_price', 'item_cnt_day', 'year_month', 'year', 'month',
#        'day', 'weekday', 'weekend', 'sale_day', 'item_category_name',
#        'item_name', 'km_cluster', 'shop_cluster', 'cnt_month'],
#       dtype='object')

# %%
df6.drop(['Unnamed: 0'],axis=1)
# Out:
#                date  shop_id  item_category_id  date_block_num  item_id  \
# 0        2013-01-01        2                40               0     8665
# 1        2013-01-01       54                 2               0     5641
# 2        2013-01-01       54                 2               0     5635
# 3        2013-01-01       54                 2               0     5574
# 4        2013-01-01       54                 2               0     5572
# ...             ...      ...               ...             ...      ...
# 2935838  2015-10-31       46                47              33    13281
# 2935839  2015-10-31       46                47              33    14956
# 2935840  2015-10-31       46                35              33     5821
# 2935841  2015-10-31       46                37              33    16985
# 2935842  2015-10-31       59                71              33    20949
#
#          item_price  item_cnt_day year_month  year  month  day  weekday  \
# ...

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
df7=df6[['shop_id','shop_cluster']]

# %%
df7
# Out:
#          shop_id  shop_cluster
# 0              2             3
# 1             54             2
# 2             54             2
# 3             54             2
# 4             54             2
# ...          ...           ...
# 2935838       46             0
# 2935839       46             0
# 2935840       46             0
# 2935841       46             0
# 2935842       59             0
#
# [2935843 rows x 2 columns]

# %%
shop_cluster=pd.read_csv('./Desktop/csv/sample.csv')

# %%
shop_cluster=shop_cluster[['shop_id','shop_cluster']]

# %%
test=pd.merge(test,shop_cluster,how='left',on='shop_id')

# %%
test=test.set_index('ID')

# %%
test
# Out:
#         shop_id  item_id  shop_cluster
# ID
# 0             5     5037             0
# 1             5     5320             0
# 2             5     5233             0
# 3             5     5232             0
# 4             5     5268             0
# ...         ...      ...           ...
# 214195       45    18454             0
# 214196       45    16188             0
# 214197       45    15757             0
# 214198       45    19648             0
# 214199       45      969             0
#
# [214200 rows x 3 columns]

# %%
train=pd.read_csv('./Desktop/kaggle_semi_project/sales_train.csv')
test=pd.read_csv('./Desktop/kaggle_semi_project/test.csv')
item_cat=pd.read_csv('./Desktop/kaggle_semi_project/item_categories.csv')
items=pd.read_csv('./Desktop/kaggle_semi_project/items.csv')
shops=pd.read_csv('./Desktop/kaggle_semi_project/shops.csv')
sample_sub=pd.read_csv('./Desktop/kaggle_semi_project/sample_submission.csv')

# %%
item_df=pd.merge(items,item_cat,how='left',on='item_category_id')

# %%
i1=item_df.drop(['item_name','item_category_name'],axis=1)

# %%
test=pd.merge(test,i1,how='left',on='item_id')

# %%
test=pd.merge(test,shop_cluster,how='left',on='shop_id')

# %%
test
# Out:
#         shop_id  item_id  item_category_id  km_cluster  shop_cluster
# 0             5     5037                19           2             0
# 1             5     5320                55           2             0
# 2             5     5233                19           2             0
# 3             5     5232                23           2             0
# 4             5     5268                20           0             0
# ...         ...      ...               ...         ...           ...
# 214195       45    18454                55           2             0
# 214196       45    16188                64           0             0
# 214197       45    15757                55           2             0
# 214198       45    19648                40           1             0
# 214199       45      969                37           2             0
#
# [214200 rows x 5 columns]

# %%
df_clust = pd.read_csv('./Desktop/csv/df_clust.csv')

# %%
df_c=df_clust[['item_category_id','km_cluster']]

# %%
test=test.set_index('ID')

# %%
test=pd.merge(test,df_c,how='left',on='item_category_id')

# %%
test
# Out:
#         shop_id  item_id  item_category_id  km_cluster
# 0             5     5037                19           2
# 1             5     5320                55           2
# 2             5     5233                19           2
# 3             5     5232                23           2
# 4             5     5268                20           0
# ...         ...      ...               ...         ...
# 214195       45    18454                55           2
# 214196       45    16188                64           0
# 214197       45    15757                55           2
# 214198       45    19648                40           1
# 214199       45      969                37           2
#
# [214200 rows x 4 columns]

# %%
df6[['item_id','item_price']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-739aa32a669c> in <module>
# ----> 1 df6[['item_id','item_price']].unique()
#
# C:\ProgramData\Anaconda3\envs\py3_7_6\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
X=pd.read_csv('./Desktop/csv/X.csv')

# %%
X=X.drop(['Unnamed: 0'],axis=1)

# %%
X.columns
# Out:
# Index(['item_price', 'item_cnt_day', 'sale_day', 'shop_id', 'item_category_id',
#        'date_block_num', 'item_id', 'weekend', 'km_cluster', 'shop_cluster',
#        'weekday_0', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6'],
#       dtype='object')

# %%
X=X.drop(['item_price','item_cnt_day','sale_day','date_block_num','weekend','weekday_0','weekday_1','weekday_2','weekday_3','weekday_4','weekday_5','weekday_6'],axis=1)

# %%
y =df6['cnt_month']

# %%
import lightgbm as lgb

lgbm = lgb.LGBMRegressor(random_state=11)
# 모델 학습
lgbm.fit(X_train, y_train)
# 예측값 생성
y_test = lgbm.predict(X_test)

# %%
y_test
# Out:
# array([4.22083846, 2.69446193, 6.51457007, ..., 3.93664778, 3.05878142,
#        3.38015763])

# %%
model1 = lgb.LGBMRegressor(random_state=11, num_iterations = 1000, learning_rate = 0.05,
                           boosting = 'dart', Metric = 'regression_l2', n_jobs=-1)
# 모델 학습
model1.fit(X_train, y_train)
# 예측값 생성
pred1 = model1.predict(test)
# Out:
# C:\ProgramData\Anaconda3\envs\py3_7_6\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))

# %%
sub_1=pd.DataFrame(pred1/5000)

# %%
sub_1.columns= ['item_cnt_month']
sub_1
# Out:
#         item_cnt_month
# 0             0.004398
# 1             0.004398
# 2             0.004398
# 3             0.004398
# 4             0.002569
# ...                ...
# 214195        0.005791
# 214196        0.004956
# 214197        0.005791
# 214198        0.004956
# 214199        0.005791
#
# [214200 rows x 1 columns]

# %%
sample.sub()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-c7179c20a838> in <module>
# ----> 1 sample.sub()
#
# NameError: name 'sample' is not defined

# %%
sample_sub1=pd.read_csv('./Desktop/kaggle_semi_project/sample_submission.csv')

# %%
sample_sub1
# Out:
#             ID  item_cnt_month
# 0            0             0.5
# 1            1             0.5
# 2            2             0.5
# 3            3             0.5
# 4            4             0.5
# ...        ...             ...
# 214195  214195             0.5
# 214196  214196             0.5
# 214197  214197             0.5
# 214198  214198             0.5
# 214199  214199             0.5
#
# [214200 rows x 2 columns]

# %%
sample_sub=pd.merge(sample_sub,sub_1,how='left',on='item_cnt_month')

# %%
sample_sub=sample_sub.drop(['item_cnt_month'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-08fa57349675> in <module>
# ----> 1 sample_sub=sample_sub.drop(['item_cnt_month'],axis=1)
#
# C:\ProgramData\Anaconda3\envs\py3_7_6\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# C:\ProgramData\Anaconda3\envs\py3_7_6\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
sample_sub=pd.concat([sample_sub,sub_1],axis=1)

# %%
sample_sub
# Out:
#             ID  item_cnt_month
# 0            0        0.004398
# 1            1        0.004398
# 2            2        0.004398
# 3            3        0.004398
# 4            4        0.002569
# ...        ...             ...
# 214195  214195        0.005791
# 214196  214196        0.004956
# 214197  214197        0.005791
# 214198  214198        0.004956
# 214199  214199        0.005791
#
# [214200 rows x 2 columns]

# %%
sample_sub.to_csv('./Desktop/csv/sample_sub.csv')

# %%
sample_sub=pd.read_csv('./Desktop/csv/sample_sub.csv')

# %%
sample_sub=sample_sub.drop(['Unnamed: 0'],axis =1)

# %%
sample_sub.to_csv('./Desktop/csv/sample_sub.csv',index=False)

# %%
sample_sub=pd.read_csv('./Desktop/csv/sample_sub.csv')

# %%
sample_sub
# Out:
#             ID  item_cnt_month
# 0            0        0.004398
# 1            1        0.004398
# 2            2        0.004398
# 3            3        0.004398
# 4            4        0.002569
# ...        ...             ...
# 214195  214195        0.005791
# 214196  214196        0.004956
# 214197  214197        0.005791
# 214198  214198        0.004956
# 214199  214199        0.005791
#
# [214200 rows x 2 columns]

# %%
X
# Out:
#          shop_id  item_category_id  item_id  km_cluster  shop_cluster
# 0              2                40     8665           1             3
# 1             54                 2     5641           0             2
# 2             54                 2     5635           0             2
# 3             54                 2     5574           0             2
# 4             54                 2     5572           0             2
# ...          ...               ...      ...         ...           ...
# 2935838       46                47    13281           0             0
# 2935839       46                47    14956           0             0
# 2935840       46                35     5821           0             0
# 2935841       46                37    16985           2             0
# 2935842       59                71    20949           2             0
#
# [2935843 rows x 5 columns]
